# %% [markdown]
# # Silver Layer Notebook Execution

# %%
tables = [
  "spotify_tracks",
  "spotify_albums", 
  "spotify_artists",
  "spotify_recently_played",
  "spotify_streaming_history"
]

for table in tables:
    print(f"A processar tabela: {table}...")
    try:
        dbutils.notebook.run(
            f"./silver_{table}", 
            timeout_seconds=600
        )
        print(f"Tabela {table} concluída com sucesso!")
    except Exception as e:
        print(f"Erro ao processar {table}: {str(e)}")
